# %%
# %matplotlib inline
from pyjmi.examples import VDP_sim
VDP_sim.run_demo()
# Out:
# Final Run Statistics: JMExamples.VDP.VDP
#
#  Number of steps                                 : 288
#  Number of function evaluations                  : 343
#  Number of Jacobian evaluations                  : 5
#  Number of function eval. due to Jacobian eval.  : 10
#  Number of error test failures                   : 9
#  Number of nonlinear iterations                  : 339
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 10.0 seconds.
# Elapsed simulation time: 0.02668 seconds.

# %%
from pyjmi.examples import crane
crane.run_demo()
# Out:
# Final Run Statistics: PyMBSModels.CraneCrab_recursive_der_state_Test
#
#  Number of steps                                 : 380
#  Number of function evaluations                  : 486
#  Number of Jacobian evaluations                  : 7
#  Number of function eval. due to Jacobian eval.  : 28
#  Number of error test failures                   : 22
#  Number of nonlinear iterations                  : 482
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10.0 seconds.
# Elapsed simulation time: 0.06361 seconds.

# %%
from pyjmi.examples import bang_control
bang_control.run_demo()
# Out:
# Total time: 0.91 seconds
# Initialization time: 0.00 seconds
# Solution time: 0.90 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import blood_glucose
blood_glucose.run_demo()
# Out:
# Final Run Statistics: JMExamples.BloodGlucose.BloodGlucose1
#
#  Number of steps                                 : 110
#  Number of function evaluations                  : 141
#  Number of Jacobian evaluations                  : 2
#  Number of function eval. due to Jacobian eval.  : 6
#  Number of error test failures                   : 3
#  Number of nonlinear iterations                  : 137
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 400.0 seconds.
# Elapsed simulation time: 0.020456 seconds.

# %%
from pyjmi.examples import blood_glucose_opt_scaled
blood_glucose_opt_scaled.run_demo()
# Out:
# Total time: 0.91 seconds
# Initialization time: 0.00 seconds
# Solution time: 0.90 seconds
# Post-processing time: 0.00 seconds
#
# Total time: 0.77 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.76 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import bounds_kinsol
bounds_kinsol.run_demo()
# Out:
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/files/BoundsDemo.mo
# IOErrorTraceback (most recent call last)
# <ipython-input-6-26d174c10b97> in <module>()
#       1 from pyjmi.examples import bounds_kinsol
# ----> 2 bounds_kinsol.run_demo()
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/bounds_kinsol.pyc in run_demo(with_plots)
#      35
#      36     log_file_name='files/bounds_kinsol.txt'
# ---> 37     m = load_fmu('BoundsDemo.fmu', log_file_name=log_file_name)
#      38
#      39     m.set_debug_logging(True)
#
# fmi.pyx in pyfmi.fmi.load_fmu (src/pyfmi/fmi.c:65647)()
#
# fmi.pyx in pyfmi.fmi.FMUModelME1.__init__ (src/pyfmi/fmi.c:27505)()
#
# fmi.pyx in pyfmi.fmi.FMUModelBase.__init__ (src/pyfmi/fmi.c:12221)()
#
# IOError: [Errno 2] No such file or directory: 'files/bounds_kinsol.txt'

# %%
from pyjmi.examples import cart_pendulum
cart_pendulum.run_demo()
# Out:
# Initialization time: 1.05 seconds
#
# Total time: 6.18 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 5.07 seconds
# Post-processing time: 0.05 seconds

# %%
from pyjmi.examples import catalyst_mixing
catalyst_mixing.run_demo()
# Out:
# Total time: 2.73 seconds
# Initialization time: 0.00 seconds
# Solution time: 2.72 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import catalytic_cracking
catalytic_cracking.run_demo()
# Out:
# Total time: 0.25 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.23 seconds
# Post-processing time: 0.00 seconds
# ** Optimal parameter values: **
# theta1 = 11.835148
# theta2 = 8.338887
# theta3 = 1.007536

# %%
from pyjmi.examples import ccpp
ccpp.run_demo()
# Out:
# Final Run Statistics: CombinedCycleStartup.Startup6Reference
#
#  Number of steps                                 : 56
#  Number of function evaluations                  : 81
#  Number of Jacobian evaluations                  : 2
#  Number of function eval. due to Jacobian eval.  : 18
#  Number of error test failures                   : 2
#  Number of nonlinear iterations                  : 77
#  Number of nonlinear convergence failures        : 0
#  Number of state function evaluations            : 57
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  5.00000000e-04   5.00000000e-04   5.00000000e-04   5.00000000e-04
#    1.00000000e-06   5.00000000e+00   5.00000000e-04   5.00000000e-04
#    1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10000.0 seconds.
# Elapsed simulation time: 0.024129 seconds.
#
# Initialization time: 3.46 seconds
#
# Total time: 8.36 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 4.74 seconds
# Post-processing time: 0.16 seconds
#
# Final Run Statistics: CombinedCycle.Optimization.Plants.CC0D_WarmStartUp
#
#  Number of steps                                 : 123
#  Number of function evaluations                  : 173
#  Number of Jacobian evaluations                  : 4
#  Number of function eval. due to Jacobian eval.  : 36
#  Number of error test failures                   : 8
#  Number of nonlinear iterations                  : 169
#  Number of nonlinear convergence failures        : 0
#  Number of state function evaluations            : 124
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  5.00000000e-04   5.00000000e-04   5.00000000e-04   5.00000000e-04
#    1.00000000e-06   1.00000000e+00   5.00000000e-04   5.00000000e-04
#    1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 4000.0 seconds.
# Elapsed simulation time: 0.095138 seconds.

# %%
from pyjmi.examples import ccpp_elimination
ccpp_elimination.run_demo()
# Out:
# Final Run Statistics: CombinedCycleStartup.Startup6Reference
#
#  Number of steps                                 : 56
#  Number of function evaluations                  : 81
#  Number of Jacobian evaluations                  : 2
#  Number of function eval. due to Jacobian eval.  : 18
#  Number of error test failures                   : 2
#  Number of nonlinear iterations                  : 77
#  Number of nonlinear convergence failures        : 0
#  Number of state function evaluations            : 57
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  5.00000000e-04   5.00000000e-04   5.00000000e-04   5.00000000e-04
#    1.00000000e-06   5.00000000e+00   5.00000000e-04   5.00000000e-04
#    1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10000.0 seconds.
# Elapsed simulation time: 0.025336 seconds.
# Number of algebraics:   221
# Eliminating variables!
# Done with elimination
# Number of variables that were eliminated:  91
# Warning: Could not find initial trajectory for variable der(u). Using initialGuess attribute value instead.
# Warning: Could not find initial trajectory for variable du. Using initialGuess attribute value instead.
# Warning: Could not find nominal trajectory for variable der(u). Using nominal attribute value instead.
# Warning: Could not find nominal trajectory for variable du. Using nominal attribute value instead.
# Warning: Could not find initial trajectory for variable der(u). Using initialGuess attribute value instead.
# Warning: Could not find initial trajectory for variable du. Using initialGuess attribute value instead.
#
# Initialization time: 1.81 seconds
#
# Total time: 4.52 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 2.52 seconds
# Post-processing time: 0.19 seconds
#
# Final Run Statistics: CombinedCycle.Optimization.Plants.CC0D_WarmStartUp
#
#  Number of steps                                 : 123
#  Number of function evaluations                  : 173
#  Number of Jacobian evaluations                  : 4
#  Number of function eval. due to Jacobian eval.  : 36
#  Number of error test failures                   : 8
#  Number of nonlinear iterations                  : 169
#  Number of nonlinear convergence failures        : 0
#  Number of state function evaluations            : 124
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  5.00000000e-04   5.00000000e-04   5.00000000e-04   5.00000000e-04
#    1.00000000e-06   1.00000000e+00   5.00000000e-04   5.00000000e-04
#    1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 4000.0 seconds.
# Elapsed simulation time: 0.090223 seconds.

# %%
from pyjmi.examples import ccpp_sym_elim
ccpp_sym_elim.run_demo()
# Out:
# System has 123 algebraic variables before elimination and 3 after.
# The three largest BLT blocks have sizes 2, 2, and 1.
#
# Warning: Could not find initial trajectory for variable der(u). Using initialGuess attribute value instead.
# Warning: Could not find initial trajectory for variable du. Using initialGuess attribute value instead.
# Warning: Could not find nominal trajectory for variable der(u). Using nominal attribute value instead.
# Warning: Could not find nominal trajectory for variable du. Using nominal attribute value instead.
# Warning: Could not find initial trajectory for variable der(u). Using initialGuess attribute value instead.
# Warning: Could not find initial trajectory for variable du. Using initialGuess attribute value instead.
#
# Initialization time: 1.35 seconds
#
# Total time: 2.49 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 1.09 seconds
# Post-processing time: 0.05 seconds

# %%
from pyjmi.examples import coloumb_friction
coloumb_friction.run_demo()
# Out:
# Total time: 0.35 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.34 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import cont_state
cont_state.run_demo()
# Out:
# Total time: 0.51 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.51 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import crane
crane.run_demo()
# Out:
# Final Run Statistics: PyMBSModels.CraneCrab_recursive_der_state_Test
#
#  Number of steps                                 : 380
#  Number of function evaluations                  : 486
#  Number of Jacobian evaluations                  : 7
#  Number of function eval. due to Jacobian eval.  : 28
#  Number of error test failures                   : 22
#  Number of nonlinear iterations                  : 482
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10.0 seconds.
# Elapsed simulation time: 0.121152 seconds.

# %%
from pyjmi.examples import crystallizer
crystallizer.run_demo()
# Out:
# Final Run Statistics: Crystallizer.SimulateCrystallizer
#
#  Number of steps                                 : 140
#  Number of function evaluations                  : 188
#  Number of Jacobian evaluations                  : 3
#  Number of function eval. due to Jacobian eval.  : 24
#  Number of error test failures                   : 5
#  Number of nonlinear iterations                  : 184
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  1.00000000e-09   1.00000000e-02   1.00000000e-05   1.00000000e-05
#    5.00000000e-08   5.00000000e-04   1.00000000e-06   1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 25.0 seconds.
# Elapsed simulation time: 0.018442 seconds.
# Total time: 4.47 seconds
# Initialization time: 0.02 seconds
# Solution time: 4.45 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import cstr
cstr.run_demo()
# Out:
#  *** Stationary point A ***
# Tc = 250.000000
# c = 956.271065
# T = 250.051971
#  *** Stationary point B ***
# Tc = 280.000000
# c = 338.775766
# T = 280.099198
# WARNING: Support for simulation of JMUs is to be discontinued. The recommended simulation framework is now the FMI, see the users-guide.
# Final Run Statistics: ---
#
#  Number of steps                                 : 78
#  Number of function evaluations                  : 91
#  Number of Jacobian evaluations                  : 42
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 91
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 0.0 - 150.0 seconds.
# Elapsed simulation time: 0.00958 seconds.
# Total time: 1.87 seconds
# Initialization time: 0.01 seconds
# Solution time: 1.85 seconds
# Post-processing time: 0.00 seconds
# WARNING: Support for simulation of JMUs is to be discontinued. The recommended simulation framework is now the FMI, see the users-guide.
# Final Run Statistics: ---
#
#  Number of steps                                 : 213
#  Number of function evaluations                  : 337
#  Number of Jacobian evaluations                  : 54
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 22
#  Number of nonlinear iterations                  : 337
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 0.0 - 150.0 seconds.
# Elapsed simulation time: 0.032481 seconds.

# %%
from pyjmi.examples import cstr2
cstr2.run_demo()
# Out:
#  *** Stationary point A ***
# u = [1.000000,1.000000]
# CAi = [0.035736,0.001799]
# Ti = [446.471014,453.258466]
#  *** Stationary point B ***
# u = [1.100000,0.900000]
# CAi = [0.014329,0.000394]
# Ti = [467.917910,470.704824]
#
# Total time: 0.70 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.68 seconds
# Post-processing time: 0.01 seconds

# %%
from pyjmi.examples import cstr_casadi
cstr_casadi.run_demo()
# Out:
#  *** Stationary point A ***
# Tc = 250.000000
# c = 956.271352
# T = 250.051971
#  *** Stationary point B ***
# Tc = 280.000000
# c = 338.775781
# T = 280.099198
# Final Run Statistics: CSTR.CSTR_Init_Optimization
#
#  Number of steps                                 : 27
#  Number of function evaluations                  : 31
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 3
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 30
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  1.00000000e-06   1.00000000e-03   3.50000000e-04]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 150.0 seconds.
# Elapsed simulation time: 0.004642 seconds.
# Initialization time: 0.23 seconds
#
# Total time: 0.34 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.11 seconds
# Post-processing time: 0.00 seconds
# Final Run Statistics: CSTR.CSTR
#
#  Number of steps                                 : 222
#  Number of function evaluations                  : 345
#  Number of Jacobian evaluations                  : 5
#  Number of function eval. due to Jacobian eval.  : 10
#  Number of error test failures                   : 32
#  Number of nonlinear iterations                  : 341
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-08
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 150.0 seconds.
# Elapsed simulation time: 0.068286 seconds.

# %%
from pyjmi.examples import cstr_constrained_mhe_example
cstr_constrained_mhe_example.run_demo()
# Out:
# Initialization time: 0.02 seconds
#
# Total time: 0.02 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.02 seconds
#
# Total time: 0.03 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.02 seconds
#
# Total time: 0.03 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000697000000002 seconds.
#
# Initialization time: 0.02 seconds
#
# Total time: 0.03 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.02 seconds
#
# Total time: 0.03 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000683000000009 seconds.
#
# Initialization time: 0.03 seconds
#
# Total time: 0.03 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.03 seconds
#
# Total time: 0.03 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000686999999999 seconds.
#
# Initialization time: 0.03 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.03 seconds
#
# Total time: 0.03 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.00122500000001 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.06 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.00118400000001 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.06 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000681999999998 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.06 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000679000000005 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000720999999999 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.06 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000689999999992 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000687999999997 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.05 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000788 seconds.
#
# Initialization time: 0.06 seconds
#
# Total time: 0.08 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.07 seconds
#
# Total time: 0.08 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.01 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000842000000006 seconds.
#
# Initialization time: 0.06 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000682000000012 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.06 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000692000000001 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000665999999995 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000843000000003 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.05 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000664 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000688000000011 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.07 seconds
#
# Total time: 0.08 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000724000000005 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000709999999998 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000715000000014 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000694999999993 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000681999999998 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000687000000013 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.06 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.00108400000001 seconds.
#
# Initialization time: 0.06 seconds
#
# Total time: 0.08 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.02 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.05 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000765000000001 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.07 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000720999999999 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.06 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000669000000002 seconds.
#
# Initialization time: 0.05 seconds
#
# Total time: 0.06 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.001569 seconds.
#
# Initialization time: 0.04 seconds
#
# Total time: 0.05 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.01 seconds
# Post-processing time: 0.00 seconds
#
#
# Initialization time: 0.04 seconds
#
# Total time: 0.04 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds
#
# Final Run Statistics: CSTR.CSTR_mhe_model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 0.1 seconds.
# Elapsed simulation time: 0.000699999999995 seconds.

# %%
from pyjmi.examples import cstr_mpc
cstr_mpc.run_demo()
# Out:
#  *** Stationary point A ***
# Tc = 250.000000
# c = 956.271065
# T = 250.051971
#  *** Stationary point B ***
# Tc = 280.000000
# c = 338.775766
# T = 280.099198
# Final Run Statistics: ---
#
#  Number of steps                                 : 11
#  Number of function evaluations                  : 11
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 11
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 0.0 - 2.0 seconds.
# Elapsed simulation time: 0.001102 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 11
#  Number of function evaluations                  : 11
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 11
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 2.0 - 4.0 seconds.
# Elapsed simulation time: 0.000786000000005 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 11
#  Number of function evaluations                  : 11
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 11
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 4.0 - 6.0 seconds.
# Elapsed simulation time: 0.00107 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 6.0 - 8.0 seconds.
# Elapsed simulation time: 0.00192199999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 8.0 - 10.0 seconds.
# Elapsed simulation time: 0.001126 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 10.0 - 12.0 seconds.
# Elapsed simulation time: 0.001594 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 12.0 - 14.0 seconds.
# Elapsed simulation time: 0.00172600000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 14.0 - 16.0 seconds.
# Elapsed simulation time: 0.003394 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 16.0 - 18.0 seconds.
# Elapsed simulation time: 0.00175399999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 18.0 - 20.0 seconds.
# Elapsed simulation time: 0.00167300000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 20.0 - 22.0 seconds.
# Elapsed simulation time: 0.002313 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 22.0 - 24.0 seconds.
# Elapsed simulation time: 0.00159000000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 24.0 - 26.0 seconds.
# Elapsed simulation time: 0.001796 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 26.0 - 28.0 seconds.
# Elapsed simulation time: 0.001603 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 28.0 - 30.0 seconds.
# Elapsed simulation time: 0.00164599999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 30.0 - 32.0 seconds.
# Elapsed simulation time: 0.00165799999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 32.0 - 34.0 seconds.
# Elapsed simulation time: 0.000984000000003 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 26
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 26
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 34.0 - 36.0 seconds.
# Elapsed simulation time: 0.00300799999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 20
#  Number of function evaluations                  : 26
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 26
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 36.0 - 38.0 seconds.
# Elapsed simulation time: 0.00139300000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 21
#  Number of function evaluations                  : 26
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 26
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 38.0 - 40.0 seconds.
# Elapsed simulation time: 0.003473 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 22
#  Number of function evaluations                  : 29
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 29
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 40.0 - 42.0 seconds.
# Elapsed simulation time: 0.002707 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 20
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 42.0 - 44.0 seconds.
# Elapsed simulation time: 0.00298500000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 44.0 - 46.0 seconds.
# Elapsed simulation time: 0.000875000000008 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 20
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 46.0 - 48.0 seconds.
# Elapsed simulation time: 0.00174900000002 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 48.0 - 50.0 seconds.
# Elapsed simulation time: 0.001597 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 50.0 - 52.0 seconds.
# Elapsed simulation time: 0.001767 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 52.0 - 54.0 seconds.
# Elapsed simulation time: 0.00204300000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 54.0 - 56.0 seconds.
# Elapsed simulation time: 0.00292499999998 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 56.0 - 58.0 seconds.
# Elapsed simulation time: 0.000812999999994 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 58.0 - 60.0 seconds.
# Elapsed simulation time: 0.00169199999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 60.0 - 62.0 seconds.
# Elapsed simulation time: 0.00105300000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 62.0 - 64.0 seconds.
# Elapsed simulation time: 0.00185400000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 64.0 - 66.0 seconds.
# Elapsed simulation time: 0.00257599999998 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 66.0 - 68.0 seconds.
# Elapsed simulation time: 0.001688 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 68.0 - 70.0 seconds.
# Elapsed simulation time: 0.002792 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 70.0 - 72.0 seconds.
# Elapsed simulation time: 0.00179900000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 72.0 - 74.0 seconds.
# Elapsed simulation time: 0.0017 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 74.0 - 76.0 seconds.
# Elapsed simulation time: 0.00183800000002 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 76.0 - 78.0 seconds.
# Elapsed simulation time: 0.000754000000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 78.0 - 80.0 seconds.
# Elapsed simulation time: 0.00146899999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 80.0 - 82.0 seconds.
# Elapsed simulation time: 0.00167999999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 82.0 - 84.0 seconds.
# Elapsed simulation time: 0.00196700000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 84.0 - 86.0 seconds.
# Elapsed simulation time: 0.00206499999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 86.0 - 88.0 seconds.
# Elapsed simulation time: 0.001116 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 88.0 - 90.0 seconds.
# Elapsed simulation time: 0.000877000000003 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 90.0 - 92.0 seconds.
# Elapsed simulation time: 0.00259299999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 92.0 - 94.0 seconds.
# Elapsed simulation time: 0.00260399999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 94.0 - 96.0 seconds.
# Elapsed simulation time: 0.00294100000002 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 96.0 - 98.0 seconds.
# Elapsed simulation time: 0.001229 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 98.0 - 100.0 seconds.
# Elapsed simulation time: 0.00185999999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 20
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 20
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 100.0 - 102.0 seconds.
# Elapsed simulation time: 0.00136900000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 20
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 20
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 102.0 - 104.0 seconds.
# Elapsed simulation time: 0.000753000000003 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 20
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 20
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 104.0 - 106.0 seconds.
# Elapsed simulation time: 0.00256599999997 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 20
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 20
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 106.0 - 108.0 seconds.
# Elapsed simulation time: 0.000957999999997 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 108.0 - 110.0 seconds.
# Elapsed simulation time: 0.00168600000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 13
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 110.0 - 112.0 seconds.
# Elapsed simulation time: 0.002892 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 20
#  Number of function evaluations                  : 24
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 24
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 112.0 - 114.0 seconds.
# Elapsed simulation time: 0.00195199999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 20
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 114.0 - 116.0 seconds.
# Elapsed simulation time: 0.00300999999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 23
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 23
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 116.0 - 118.0 seconds.
# Elapsed simulation time: 0.00150300000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 19
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 118.0 - 120.0 seconds.
# Elapsed simulation time: 0.00161299999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 120.0 - 122.0 seconds.
# Elapsed simulation time: 0.00148000000002 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 122.0 - 124.0 seconds.
# Elapsed simulation time: 0.00159300000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 22
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 22
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 124.0 - 126.0 seconds.
# Elapsed simulation time: 0.00467600000002 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 18
#  Number of function evaluations                  : 21
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 21
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 126.0 - 128.0 seconds.
# Elapsed simulation time: 0.00129799999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 17
#  Number of function evaluations                  : 20
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 20
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 128.0 - 130.0 seconds.
# Elapsed simulation time: 0.001484 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 17
#  Number of function evaluations                  : 20
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 20
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 130.0 - 132.0 seconds.
# Elapsed simulation time: 0.00147699999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 17
#  Number of function evaluations                  : 20
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 20
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 132.0 - 134.0 seconds.
# Elapsed simulation time: 0.002464 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 17
#  Number of function evaluations                  : 19
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 19
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 134.0 - 136.0 seconds.
# Elapsed simulation time: 0.001608 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 16
#  Number of function evaluations                  : 19
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 19
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 136.0 - 138.0 seconds.
# Elapsed simulation time: 0.00199700000002 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 16
#  Number of function evaluations                  : 19
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 19
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 138.0 - 140.0 seconds.
# Elapsed simulation time: 0.00143800000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 16
#  Number of function evaluations                  : 18
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 18
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 140.0 - 142.0 seconds.
# Elapsed simulation time: 0.001833 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 15
#  Number of function evaluations                  : 18
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 18
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 142.0 - 144.0 seconds.
# Elapsed simulation time: 0.00130700000003 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 15
#  Number of function evaluations                  : 18
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 18
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 144.0 - 146.0 seconds.
# Elapsed simulation time: 0.002377 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 15
#  Number of function evaluations                  : 17
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 17
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 146.0 - 148.0 seconds.
# Elapsed simulation time: 0.00149199999998 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 17
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 17
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 148.0 - 150.0 seconds.
# Elapsed simulation time: 0.00135499999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 17
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 17
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 150.0 - 152.0 seconds.
# Elapsed simulation time: 0.00239099999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 17
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 17
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 152.0 - 154.0 seconds.
# Elapsed simulation time: 0.00156000000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 16
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 16
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 154.0 - 156.0 seconds.
# Elapsed simulation time: 0.00149299999998 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 16
#  Number of Jacobian evaluations                  : 12
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 16
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 156.0 - 158.0 seconds.
# Elapsed simulation time: 0.00144699999998 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 16
#  Number of Jacobian evaluations                  : 10
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 16
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 158.0 - 160.0 seconds.
# Elapsed simulation time: 0.00148999999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 16
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 16
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 160.0 - 162.0 seconds.
# Elapsed simulation time: 0.010245 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 14
#  Number of function evaluations                  : 16
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 16
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 162.0 - 164.0 seconds.
# Elapsed simulation time: 0.001397 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 13
#  Number of function evaluations                  : 16
#  Number of Jacobian evaluations                  : 10
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 16
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 164.0 - 166.0 seconds.
# Elapsed simulation time: 0.00214399999999 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 13
#  Number of function evaluations                  : 16
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 16
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 166.0 - 168.0 seconds.
# Elapsed simulation time: 0.00176300000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 13
#  Number of function evaluations                  : 15
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 15
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 168.0 - 170.0 seconds.
# Elapsed simulation time: 0.00137000000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 13
#  Number of function evaluations                  : 15
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 15
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 170.0 - 172.0 seconds.
# Elapsed simulation time: 0.000461000000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 12
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 10
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 14
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 172.0 - 174.0 seconds.
# Elapsed simulation time: 0.00276399999998 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 12
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 14
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 174.0 - 176.0 seconds.
# Elapsed simulation time: 0.002352 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 12
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 14
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 176.0 - 178.0 seconds.
# Elapsed simulation time: 0.00285700000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 12
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 14
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 178.0 - 180.0 seconds.
# Elapsed simulation time: 0.001508 seconds.

# %%
from pyjmi.examples import cstr_mpc_casadi
cstr_mpc_casadi.run_demo()
# Out:
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 24
#  Number of function evaluations                  : 33
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 29
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 150.0 seconds.
# Elapsed simulation time: 0.00315999999998 seconds.
# The prediction horizon is 99
# Warning: Could not find initial trajectory for variable T_slack. Using initialGuess attribute value instead.
# Warning: Could not find initial trajectory for variable T_slack. Using initialGuess attribute value instead.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 3.0 seconds.
# Elapsed simulation time: 0.00240500000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 3.0 - 6.0 seconds.
# Elapsed simulation time: 0.00144399999999 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 6.0 - 9.0 seconds.
# Elapsed simulation time: 0.00142099999999 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 13
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 9
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 9.0 - 12.0 seconds.
# Elapsed simulation time: 0.001295 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 13
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 9
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 12.0 - 15.0 seconds.
# Elapsed simulation time: 0.00252400000002 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 15.0 - 18.0 seconds.
# Elapsed simulation time: 0.00108600000002 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 18.0 - 21.0 seconds.
# Elapsed simulation time: 0.00113400000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 21.0 - 24.0 seconds.
# Elapsed simulation time: 0.002004 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 11
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 7
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 24.0 - 27.0 seconds.
# Elapsed simulation time: 0.001226 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 27.0 - 30.0 seconds.
# Elapsed simulation time: 0.00109800000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 12
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 8
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 30.0 - 33.0 seconds.
# Elapsed simulation time: 0.000676999999996 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 12
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 8
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 33.0 - 36.0 seconds.
# Elapsed simulation time: 0.00125199999999 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 7
#  Number of function evaluations                  : 15
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 11
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 36.0 - 39.0 seconds.
# Elapsed simulation time: 0.00158299999998 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 12
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 8
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 39.0 - 42.0 seconds.
# Elapsed simulation time: 0.00210000000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 12
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 8
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 42.0 - 45.0 seconds.
# Elapsed simulation time: 0.00151 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 45.0 - 48.0 seconds.
# Elapsed simulation time: 0.001069 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 12
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 8
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 48.0 - 51.0 seconds.
# Elapsed simulation time: 0.00271899999998 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 12
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 8
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 51.0 - 54.0 seconds.
# Elapsed simulation time: 0.00136900000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 54.0 - 57.0 seconds.
# Elapsed simulation time: 0.00165100000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 8
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 4
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 57.0 - 60.0 seconds.
# Elapsed simulation time: 0.000909000000007 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 9
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 5
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 60.0 - 63.0 seconds.
# Elapsed simulation time: 0.000260999999995 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 8
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 4
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 63.0 - 66.0 seconds.
# Elapsed simulation time: 0.000952000000012 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 11
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 7
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 66.0 - 69.0 seconds.
# Elapsed simulation time: 0.001239 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 69.0 - 72.0 seconds.
# Elapsed simulation time: 0.000355999999982 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 8
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 4
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 72.0 - 75.0 seconds.
# Elapsed simulation time: 0.000608 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 9
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 5
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 75.0 - 78.0 seconds.
# Elapsed simulation time: 0.000417999999996 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 8
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 4
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 78.0 - 81.0 seconds.
# Elapsed simulation time: 0.000887000000006 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 81.0 - 84.0 seconds.
# Elapsed simulation time: 0.000564999999995 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 84.0 - 87.0 seconds.
# Elapsed simulation time: 0.00105299999998 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 87.0 - 90.0 seconds.
# Elapsed simulation time: 0.00145000000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 90.0 - 93.0 seconds.
# Elapsed simulation time: 0.00141699999998 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 93.0 - 96.0 seconds.
# Elapsed simulation time: 0.001451 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 96.0 - 99.0 seconds.
# Elapsed simulation time: 0.00145599999999 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 99.0 - 102.0 seconds.
# Elapsed simulation time: 0.00175300000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 7
#  Number of function evaluations                  : 15
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 11
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 102.0 - 105.0 seconds.
# Elapsed simulation time: 0.00278799999998 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 105.0 - 108.0 seconds.
# Elapsed simulation time: 0.000544000000019 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 6
#  Number of function evaluations                  : 14
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 10
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 108.0 - 111.0 seconds.
# Elapsed simulation time: 0.001429 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 5
#  Number of function evaluations                  : 11
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 7
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 111.0 - 114.0 seconds.
# Elapsed simulation time: 0.00123100000002 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 114.0 - 117.0 seconds.
# Elapsed simulation time: 0.001068 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 117.0 - 120.0 seconds.
# Elapsed simulation time: 0.00171599999999 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 120.0 - 123.0 seconds.
# Elapsed simulation time: 0.00073900000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 123.0 - 126.0 seconds.
# Elapsed simulation time: 0.001026 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 126.0 - 129.0 seconds.
# Elapsed simulation time: 0.001002 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 129.0 - 132.0 seconds.
# Elapsed simulation time: 0.00151700000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 4
#  Number of function evaluations                  : 10
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 6
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 132.0 - 135.0 seconds.
# Elapsed simulation time: 0.001081 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 9
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 5
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 135.0 - 138.0 seconds.
# Elapsed simulation time: 0.001329 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 9
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 5
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 138.0 - 141.0 seconds.
# Elapsed simulation time: 0.00116800000001 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 9
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 5
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 141.0 - 144.0 seconds.
# Elapsed simulation time: 0.001105 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 9
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 5
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 144.0 - 147.0 seconds.
# Elapsed simulation time: 0.000920000000008 seconds.
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 9
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 5
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 147.0 - 150.0 seconds.
# Elapsed simulation time: 0.000895999999983 seconds.
# 1: Solve_Succeeded: 35 iterations in 0.14267 seconds
# 2: Solve_Succeeded: 12 iterations in 0.025114 seconds
# 3: Solve_Succeeded: 11 iterations in 0.022858 seconds
# 4: Solve_Succeeded: 12 iterations in 0.029671 seconds
# 5: Solve_Succeeded: 10 iterations in 0.021446 seconds
# 6: Solve_Succeeded: 16 iterations in 0.043831 seconds
# 7: Solve_Succeeded: 13 iterations in 0.03712 seconds
# 8: Solve_Succeeded: 11 iterations in 0.023884 seconds
# 9: Solve_Succeeded: 12 iterations in 0.030065 seconds
# 10: Solve_Succeeded: 10 iterations in 0.021473 seconds
# 11: Solve_Succeeded: 10 iterations in 0.023902 seconds
# 12: Solve_Succeeded: 10 iterations in 0.021976 seconds
# 13: Solve_Succeeded: 11 iterations in 0.026117 seconds
# 14: Solve_Succeeded: 11 iterations in 0.021746 seconds
# 15: Solve_Succeeded: 9 iterations in 0.029566 seconds
# 16: Solve_Succeeded: 23 iterations in 0.048524 seconds
# 17: Solve_Succeeded: 16 iterations in 0.046639 seconds
# 18: Solve_Succeeded: 12 iterations in 0.039481 seconds
# 19: Solve_Succeeded: 16 iterations in 0.035529 seconds
# 20: Solve_Succeeded: 8 iterations in 0.018965 seconds
# 21: Solve_Succeeded: 15 iterations in 0.03533 seconds
# 22: Solve_Succeeded: 10 iterations in 0.026052 seconds
# 23: Solve_Succeeded: 23 iterations in 0.048132 seconds
# 24: Solve_Succeeded: 13 iterations in 0.025393 seconds
# 25: Solve_Succeeded: 5 iterations in 0.011882 seconds
# 26: Solve_Succeeded: 5 iterations in 0.012439 seconds
# 27: Solve_Succeeded: 5 iterations in 0.012176 seconds
# 28: Solve_Succeeded: 5 iterations in 0.011435 seconds
# 29: Solve_Succeeded: 5 iterations in 0.014072 seconds
# 30: Solve_Succeeded: 5 iterations in 0.013065 seconds
# 31: Solve_Succeeded: 5 iterations in 0.015139 seconds
# 32: Solve_Succeeded: 6 iterations in 0.014742 seconds
# 33: Solve_Succeeded: 5 iterations in 0.012806 seconds
# 34: Solve_Succeeded: 5 iterations in 0.012353 seconds
# 35: Solve_Succeeded: 6 iterations in 0.02353 seconds
# 36: Solve_Succeeded: 5 iterations in 0.011453 seconds
# 37: Solve_Succeeded: 5 iterations in 0.012818 seconds
# 38: Solve_Succeeded: 5 iterations in 0.012159 seconds
# 39: Solve_Succeeded: 5 iterations in 0.012574 seconds
# 40: Solve_Succeeded: 5 iterations in 0.011517 seconds
# 41: Solve_Succeeded: 5 iterations in 0.011566 seconds
# 42: Solve_Succeeded: 5 iterations in 0.016261 seconds
# 43: Solve_Succeeded: 5 iterations in 0.021359 seconds
# 44: Solve_Succeeded: 5 iterations in 0.011583 seconds
# 45: Solve_Succeeded: 5 iterations in 0.013607 seconds
# 46: Solve_Succeeded: 5 iterations in 0.011527 seconds
# 47: Solve_Succeeded: 5 iterations in 0.0211 seconds
# 48: Solve_Succeeded: 5 iterations in 0.012196 seconds
# 49: Solve_Succeeded: 5 iterations in 0.019111 seconds
# 50: Solve_Succeeded: 5 iterations in 0.013516 seconds
#
# Total time for 50 samples (average time in parenthesis).
#
# Initialization time: 0.15 seconds
#
# Total time: 1.40 seconds             (0.028)
# Pre-processing time: 0.02 seconds    (0.000)
# Solution time: 1.23 seconds          (0.025)
# Post-processing time: 0.15 seconds   (0.003)
#
# Largest total time for one sample (nbr 1): 0.15 seconds
# The sample period is 3.00 seconds
#
#
# Initialization time: 0.18 seconds
#
# Total time: 0.29 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.10 seconds
# Post-processing time: 0.01 seconds

# %%
from pyjmi.examples import delayed_feedback_opt
delayed_feedback_opt.run_demo()
# Out:
# Initialization time: 0.09 seconds
#
# Total time: 0.10 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.00 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import dist1_init_sim
dist1_init_sim.run_demo()
# Out:
# (Tray index, x_i_A, y_i_A)
# (1, 0.935419, 0.958635)
# (2, 0.900526, 0.935419)
# (3, 0.862296, 0.909249)
# (4, 0.821699, 0.880577)
# (5, 0.779991, 0.850129)
# (6, 0.738572, 0.818848)
# (7, 0.698805, 0.787784)
# (8, 0.661843, 0.757959)
# (9, 0.628508, 0.730237)
# (10, 0.599253, 0.705236)
# (11, 0.574186, 0.683294)
# (12, 0.553144, 0.664494)
# (13, 0.535785, 0.648713)
# (14, 0.521666, 0.635693)
# (15, 0.510315, 0.625104)
# (16, 0.501275, 0.616591)
# (17, 0.494129, 0.609811)
# (18, 0.485450, 0.601516)
# (19, 0.474203, 0.590667)
# (20, 0.459803, 0.576608)
# (21, 0.441645, 0.558608)
# (22, 0.419187, 0.535911)
# (23, 0.392064, 0.507839)
# (24, 0.360231, 0.473934)
# (25, 0.324105, 0.434144)
# (26, 0.284637, 0.388987)
# (27, 0.243266, 0.339651)
# (28, 0.201745, 0.287938)
# (29, 0.161848, 0.236036)
# (30, 0.125086, 0.186165)
# (31, 0.092496, 0.140212)
# (32, 0.064581, 0.099475)
# (Tray index, x_i_B, y_i_B)
# (1, 0.843110, 0.895814)
# (2, 0.770573, 0.843110)
# (3, 0.707611, 0.794752)
# (4, 0.655539, 0.752777)
# (5, 0.614168, 0.718063)
# (6, 0.582336, 0.690482)
# (7, 0.558442, 0.669261)
# (8, 0.540836, 0.653331)
# (9, 0.528042, 0.641594)
# (10, 0.518837, 0.633065)
# (11, 0.512262, 0.626928)
# (12, 0.507589, 0.622545)
# (13, 0.504281, 0.619430)
# (14, 0.501945, 0.617224)
# (15, 0.500298, 0.615666)
# (16, 0.499138, 0.614569)
# (17, 0.498323, 0.613796)
# (18, 0.496572, 0.612134)
# (19, 0.494116, 0.609799)
# (20, 0.490683, 0.606525)
# (21, 0.485899, 0.601947)
# (22, 0.479269, 0.595568)
# (23, 0.470150, 0.586729)
# (24, 0.457730, 0.574569)
# (25, 0.441047, 0.558010)
# (26, 0.419045, 0.535766)
# (27, 0.390721, 0.506430)
# (28, 0.355372, 0.468665)
# (29, 0.312923, 0.421533)
# (30, 0.264246, 0.364934)
# (31, 0.211293, 0.300032)
# (32, 0.156890, 0.229427)
# Final Run Statistics: JMExamples.Distillation.Distillation1Inputstep
#
#  Number of steps                                 : 34
#  Number of function evaluations                  : 46
#  Number of Jacobian evaluations                  : 2
#  Number of function eval. due to Jacobian eval.  : 64
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 38
#  Number of nonlinear convergence failures        : 0
#  Number of time events                           : 1
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 50.0 seconds.
# Elapsed simulation time: 0.0095 seconds.
# t =  array([  0.00000000e+00,   3.43225906e-04,   3.43260229e+00,
#          1.00000000e+01,   1.00000000e+01,   1.00428645e+01,
#          1.00857291e+01,   1.01598123e+01,   1.02338955e+01,
#          1.03847147e+01,   1.05355339e+01,   1.06863531e+01,
#          1.08371724e+01,   1.09879916e+01,   1.12430923e+01,
#          1.14981931e+01,   1.19177587e+01,   1.23373243e+01,
#          1.30914018e+01,   1.38454794e+01,   1.45995569e+01,
#          1.53536345e+01,   1.61077121e+01,   1.74924425e+01,
#          1.88771729e+01,   2.02619033e+01,   2.24788821e+01,
#          2.46958609e+01,   2.69128396e+01,   3.05473018e+01,
#          3.41817640e+01,   3.78162262e+01,   4.14506884e+01,
#          4.50851506e+01,   4.87196128e+01,   5.00000000e+01])
# x1 =  array([ 0.93541944,  0.93541944,  0.93541944,  0.93541943,  0.93541943,
#         0.93541006,  0.9353922 ,  0.93534706,  0.93528331,  0.93510283,
#         0.934866  ,  0.93458526,  0.93427027,  0.93392816,  0.93330441,
#         0.93263466,  0.93146172,  0.93022602,  0.92790734,  0.92552272,
#         0.9231066 ,  0.92067344,  0.91823244,  0.91375589,  0.90932537,
#         0.90497896,  0.89827083,  0.89195823,  0.88610978,  0.87761242,
#         0.87048347,  0.86461898,  0.85987096,  0.85609528,  0.85312042,
#         0.85222969])
# x8 =  array([ 0.66184259,  0.66184259,  0.66184259,  0.66184258,  0.66184258,
#         0.66152597,  0.66120964,  0.66066341,  0.66011791,  0.6590099 ,
#         0.65790527,  0.65680408,  0.65570643,  0.6546124 ,  0.65277074,
#         0.65094083,  0.64795966,  0.64501825,  0.63984903,  0.63485274,
#         0.63004852,  0.62544652,  0.62104948,  0.61349801,  0.60660165,
#         0.60032238,  0.59144001,  0.58383908,  0.57734806,  0.56871471,
#         0.56207958,  0.5570034 ,  0.55311816,  0.55015131,  0.54788992,
#         0.54723002])
# x16 =  array([ 0.50127509,  0.50127509,  0.50127508,  0.50127508,  0.50127508,
#         0.50120577,  0.5011432 ,  0.5010454 ,  0.50095978,  0.5008129 ,
#         0.50069304,  0.50059081,  0.50050057,  0.50041907,  0.50029533,
#         0.50018638,  0.50003155,  0.49990027,  0.49970786,  0.49955512,
#         0.49943134,  0.49933055,  0.49924829,  0.49913447,  0.49905465,
#         0.49899765,  0.4989388 ,  0.49890568,  0.4988887 ,  0.49888086,
#         0.49888813,  0.49890456,  0.49892544,  0.4989473 ,  0.49896845,
#         0.49897566])
# x32 =  array([ 0.06458062,  0.06458062,  0.06458062,  0.06458061,  0.06458061,
#         0.06464624,  0.0647169 ,  0.06484714,  0.0649876 ,  0.06530003,
#         0.06564131,  0.06600466,  0.06638521,  0.06677957,  0.06747023,
#         0.06818554,  0.06940159,  0.07065355,  0.07296085,  0.07530675,
#         0.07766762,  0.08003052,  0.08238597,  0.08666684,  0.09085592,
#         0.09492345,  0.10113594,  0.10693616,  0.11229924,  0.12013127,
#         0.12680856,  0.1324301 ,  0.13710614,  0.14094777,  0.14408248,
#         0.14504363])
