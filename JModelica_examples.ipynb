# %%
# %matplotlib inline
from pyjmi.examples import VDP_sim
VDP_sim.run_demo()
# Out:
# Final Run Statistics: JMExamples.VDP.VDP
#
#  Number of steps                                 : 288
#  Number of function evaluations                  : 343
#  Number of Jacobian evaluations                  : 5
#  Number of function eval. due to Jacobian eval.  : 10
#  Number of error test failures                   : 9
#  Number of nonlinear iterations                  : 339
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 10.0 seconds.
# Elapsed simulation time: 0.04244 seconds.

# %%
from pyjmi.examples import crane
crane.run_demo()
# Out:
# Final Run Statistics: PyMBSModels.CraneCrab_recursive_der_state_Test
#
#  Number of steps                                 : 380
#  Number of function evaluations                  : 486
#  Number of Jacobian evaluations                  : 7
#  Number of function eval. due to Jacobian eval.  : 28
#  Number of error test failures                   : 22
#  Number of nonlinear iterations                  : 482
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10.0 seconds.
# Elapsed simulation time: 0.083775 seconds.

# %%
from pyjmi.examples import ast_example
ast_example.run_demo()
# Out:
# JVM started.
# The package Modelica.UsersGuide has 40 hierachically contained classes
# The package Modelica.Blocks has 392 hierachically contained classes
# The package Modelica.ComplexBlocks has 51 hierachically contained classes
# The package Modelica.StateGraph has 66 hierachically contained classes
# The package Modelica.Electrical has 1201 hierachically contained classes
# The package Modelica.Magnetic has 312 hierachically contained classes
# The package Modelica.Mechanics has 573 hierachically contained classes
# The package Modelica.Fluid has 689 hierachically contained classes
# The package Modelica.Media has 1479 hierachically contained classes
# The package Modelica.Thermal has 98 hierachically contained classes
# The package Modelica.Math has 238 hierachically contained classes
# The package Modelica.ComplexMath has 31 hierachically contained classes
# The package Modelica.Utilities has 106 hierachically contained classes
# ...

# %%
from pyjmi.examples import bang_control
bang_control.run_demo()
# Out:
# Total time: 1.26 seconds
# Initialization time: 0.01 seconds
# Solution time: 1.25 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import blood_glucose
blood_glucose.run_demo()
# Out:
# Final Run Statistics: JMExamples.BloodGlucose.BloodGlucose1
#
#  Number of steps                                 : 110
#  Number of function evaluations                  : 141
#  Number of Jacobian evaluations                  : 2
#  Number of function eval. due to Jacobian eval.  : 6
#  Number of error test failures                   : 3
#  Number of nonlinear iterations                  : 137
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 400.0 seconds.
# Elapsed simulation time: 0.017048 seconds.

# %%
from pyjmi.examples import blood_glucose_opt_scaled
blood_glucose_opt_scaled.run_demo()
# Out:
# Total time: 1.09 seconds
# Initialization time: 0.01 seconds
# Solution time: 1.08 seconds
# Post-processing time: 0.00 seconds
#
# Total time: 1.05 seconds
# Initialization time: 0.01 seconds
# Solution time: 1.04 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import bounds_kinsol
bounds_kinsol.run_demo()
# Out:
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/files/BoundsDemo.mo
# IOErrorTraceback (most recent call last)
# <ipython-input-7-26d174c10b97> in <module>()
#       1 from pyjmi.examples import bounds_kinsol
# ----> 2 bounds_kinsol.run_demo()
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/bounds_kinsol.pyc in run_demo(with_plots)
#      35
#      36     log_file_name='files/bounds_kinsol.txt'
# ---> 37     m = load_fmu('BoundsDemo.fmu', log_file_name=log_file_name)
#      38
#      39     m.set_debug_logging(True)
#
# fmi.pyx in pyfmi.fmi.load_fmu (src/pyfmi/fmi.c:65647)()
#
# fmi.pyx in pyfmi.fmi.FMUModelME1.__init__ (src/pyfmi/fmi.c:27505)()
#
# fmi.pyx in pyfmi.fmi.FMUModelBase.__init__ (src/pyfmi/fmi.c:12221)()
#
# IOError: [Errno 2] No such file or directory: 'files/bounds_kinsol.txt'

# %%
from pyjmi.examples import cart_pendulum
cart_pendulum.run_demo()
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-8-af676a9605a8> in <module>()
#       1 from pyjmi.examples import cart_pendulum
# ----> 2 cart_pendulum.run_demo()
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/cart_pendulum.pyc in run_demo(with_plots)
#      49     # Create compiler and compile the pendulum model
#      50     file_path = os.path.join(get_files_path(), "cart_pendulum.mop")
# ---> 51     pend_opt = transfer_optimization_problem("CartPendulum", file_path)
#      52
#      53     # Define number of elements in the discretization grid and
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/casadi_interface.pyc in transfer_optimization_problem(class_name, file_name, compiler_options, compiler_log_level, accept_model)
#     151                                    compiler_options=compiler_options,
#     152                                    compiler_log_level=compiler_log_level,
# ...

# %%
from pyjmi.examples import catalyst_mixing
catalyst_mixing.run_demo()
# Out:
# Total time: 3.09 seconds
# Initialization time: 0.01 seconds
# Solution time: 3.08 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import catalytic_cracking
catalytic_cracking.run_demo()
# Out:
# Total time: 0.23 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.21 seconds
# Post-processing time: 0.00 seconds
# ** Optimal parameter values: **
# theta1 = 11.835148
# theta2 = 8.338887
# theta3 = 1.007536

# %%
from pyjmi.examples import ccpp
ccpp.run_demo()
# Out:
# Final Run Statistics: CombinedCycleStartup.Startup6Reference
#
#  Number of steps                                 : 56
#  Number of function evaluations                  : 81
#  Number of Jacobian evaluations                  : 2
#  Number of function eval. due to Jacobian eval.  : 18
#  Number of error test failures                   : 2
#  Number of nonlinear iterations                  : 77
#  Number of nonlinear convergence failures        : 0
#  Number of state function evaluations            : 57
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  5.00000000e-04   5.00000000e-04   5.00000000e-04   5.00000000e-04
#    1.00000000e-06   5.00000000e+00   5.00000000e-04   5.00000000e-04
#    1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10000.0 seconds.
# ...

# %%
from pyjmi.examples import ccpp_elimination
ccpp_elimination.run_demo()
# Out:
# Final Run Statistics: CombinedCycleStartup.Startup6Reference
#
#  Number of steps                                 : 56
#  Number of function evaluations                  : 81
#  Number of Jacobian evaluations                  : 2
#  Number of function eval. due to Jacobian eval.  : 18
#  Number of error test failures                   : 2
#  Number of nonlinear iterations                  : 77
#  Number of nonlinear convergence failures        : 0
#  Number of state function evaluations            : 57
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  5.00000000e-04   5.00000000e-04   5.00000000e-04   5.00000000e-04
#    1.00000000e-06   5.00000000e+00   5.00000000e-04   5.00000000e-04
#    1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10000.0 seconds.
# ...

# %%
from pyjmi.examples import ccpp_sym_elim
ccpp_sym_elim.run_demo()
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-14-e17165b0401e> in <module>()
#       1 from pyjmi.examples import ccpp_sym_elim
# ----> 2 ccpp_sym_elim.run_demo()
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/ccpp_sym_elim.pyc in run_demo(with_plots)
#      45     file_paths = (os.path.join(get_files_path(), "CombinedCycle.mo"),
#      46                   os.path.join(get_files_path(), "CombinedCycleStartup.mop"))
# ---> 47     op = transfer_optimization_problem("CombinedCycleStartup.Startup6", file_paths)
#      48
#      49     # Set elimination options
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/casadi_interface.pyc in transfer_optimization_problem(class_name, file_name, compiler_options, compiler_log_level, accept_model)
#     151                                    compiler_options=compiler_options,
#     152                                    compiler_log_level=compiler_log_level,
# ...

# %%
from pyjmi.examples import coloumb_friction
coloumb_friction.run_demo()
# Out:
# Total time: 0.40 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.39 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import cont_state
cont_state.run_demo()
# Out:
# Total time: 0.73 seconds
# Initialization time: 0.01 seconds
# Solution time: 0.72 seconds
# Post-processing time: 0.00 seconds

# %%
from pyjmi.examples import crane
crane.run_demo()
# Out:
# Final Run Statistics: PyMBSModels.CraneCrab_recursive_der_state_Test
#
#  Number of steps                                 : 380
#  Number of function evaluations                  : 486
#  Number of Jacobian evaluations                  : 7
#  Number of function eval. due to Jacobian eval.  : 28
#  Number of error test failures                   : 22
#  Number of nonlinear iterations                  : 482
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 10.0 seconds.
# Elapsed simulation time: 0.08494 seconds.

# %%
from pyjmi.examples import crystallizer
crystallizer.run_demo()
# Out:
# Final Run Statistics: Crystallizer.SimulateCrystallizer
#
#  Number of steps                                 : 140
#  Number of function evaluations                  : 188
#  Number of Jacobian evaluations                  : 3
#  Number of function eval. due to Jacobian eval.  : 24
#  Number of error test failures                   : 5
#  Number of nonlinear iterations                  : 184
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  1.00000000e-09   1.00000000e-02   1.00000000e-05   1.00000000e-05
#    5.00000000e-08   5.00000000e-04   1.00000000e-06   1.00000000e-06]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 25.0 seconds.
# Elapsed simulation time: 0.027639 seconds.
# Total time: 5.78 seconds
# ...

# %%
from pyjmi.examples import cstr
cstr.run_demo()
# Out:
#  *** Stationary point A ***
# Tc = 250.000000
# c = 956.271065
# T = 250.051971
#  *** Stationary point B ***
# Tc = 280.000000
# c = 338.775766
# T = 280.099198
# WARNING: Support for simulation of JMUs is to be discontinued. The recommended simulation framework is now the FMI, see the users-guide.
# Final Run Statistics: ---
#
#  Number of steps                                 : 78
#  Number of function evaluations                  : 91
#  Number of Jacobian evaluations                  : 42
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 91
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 0.0 - 150.0 seconds.
# ...

# %%
from pyjmi.examples import cstr2
cstr2.run_demo()
# Out:
#  *** Stationary point A ***
# u = [1.000000,1.000000]
# CAi = [0.035736,0.001799]
# Ti = [446.471014,453.258466]
#  *** Stationary point B ***
# u = [1.100000,0.900000]
# CAi = [0.014329,0.000394]
# Ti = [467.917910,470.704824]
#
# Total time: 0.75 seconds
# Initialization time: 0.02 seconds
# Solution time: 0.73 seconds
# Post-processing time: 0.01 seconds

# %%
from pyjmi.examples import cstr_casadi
cstr_casadi.run_demo()
# Out:
#  *** Stationary point A ***
# Tc = 250.000000
# c = 956.271352
# T = 250.051971
#  *** Stationary point B ***
# Tc = 280.000000
# c = 338.775781
# T = 280.099198
# Final Run Statistics: CSTR.CSTR_Init_Optimization
#
#  Number of steps                                 : 27
#  Number of function evaluations                  : 31
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 3
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 30
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [  1.00000000e-06   1.00000000e-03   3.50000000e-04]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 150.0 seconds.
# ...

# %%
from pyjmi.examples import cstr_constrained_mhe_example
cstr_constrained_mhe_example.run_demo()
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-23-36e5051b9a98> in <module>()
#       1 from pyjmi.examples import cstr_constrained_mhe_example
# ----> 2 cstr_constrained_mhe_example.run_demo()
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/cstr_constrained_mhe_example.py in run_demo(with_plots)
#      47                         file_path,
#      48                         accept_model = True,
# ---> 49                         compiler_options= {"state_initial_equations":True})
#      50     #Transfer the constrained OptimizationProblem from the Optimica model
#      51     #using "state_initial_equations"
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/casadi_interface.pyc in transfer_optimization_problem(class_name, file_name, compiler_options, compiler_log_level, accept_model)
#     151                                    compiler_options=compiler_options,
#     152                                    compiler_log_level=compiler_log_level,
# ...

# %%
from pyjmi.examples import cstr_mpc
cstr_mpc.run_demo()
# Out:
#  *** Stationary point A ***
# Tc = 250.000000
# c = 956.271065
# T = 250.051971
#  *** Stationary point B ***
# Tc = 280.000000
# c = 338.775766
# T = 280.099198
# Final Run Statistics: ---
#
#  Number of steps                                 : 11
#  Number of function evaluations                  : 11
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 0
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 11
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                       : IDA (BDF)
#  Maximal order                : 5
#  Suppressed algebr. variables : False
#  Tolerances (absolute)        : 1e-06
#  Tolerances (relative)        : 1e-06
#
# Simulation interval    : 0.0 - 2.0 seconds.
# Elapsed simulation time: 0.00170900000001 seconds.
# Final Run Statistics: ---
#
#  Number of steps                                 : 11
# ...

# %%
from pyjmi.examples import cstr_mpc_casadi
cstr_mpc_casadi.run_demo()
# Out:
# Final Run Statistics: CSTR.CSTR_MPC_Model
#
#  Number of steps                                 : 24
#  Number of function evaluations                  : 33
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 2
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 29
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [ 0.001    0.00035]
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 150.0 seconds.
# Elapsed simulation time: 0.00390299999998 seconds.
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-25-443f8a26b6ce> in <module>()
#       1 from pyjmi.examples import cstr_mpc_casadi
# ...

# %%
from pyjmi.examples import delayed_feedback_opt
delayed_feedback_opt.run_demo()
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-26-2e5abaaf3b3b> in <module>()
#       1 from pyjmi.examples import delayed_feedback_opt
# ----> 2 delayed_feedback_opt.run_demo()
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/examples/delayed_feedback_opt.py in run_demo(with_plots)
#      31     # Compile and load optimization problem
#      32     file_path = os.path.join(get_files_path(), "DelayedFeedbackOpt.mop")
# ---> 33     opt = transfer_optimization_problem("DelayTest", file_path)
#      34
#      35     # Set value for u2(t) when t < delay
#
# /home/jserver/workspace/JModelica.org/Python/pyjmi/casadi_interface.pyc in transfer_optimization_problem(class_name, file_name, compiler_options, compiler_log_level, accept_model)
#     151                                    compiler_options=compiler_options,
#     152                                    compiler_log_level=compiler_log_level,
# --> 153                                    accept_model=accept_model)
# ...

# %%
from pyjmi.examples import dist1_init_sim
dist1_init_sim.run_demo()
# Out:
# (Tray index, x_i_A, y_i_A)
# (1, 0.935419, 0.958635)
# (2, 0.900526, 0.935419)
# (3, 0.862296, 0.909249)
# (4, 0.821699, 0.880577)
# (5, 0.779991, 0.850129)
# (6, 0.738572, 0.818848)
# (7, 0.698805, 0.787784)
# (8, 0.661843, 0.757959)
# (9, 0.628508, 0.730237)
# (10, 0.599253, 0.705236)
# (11, 0.574186, 0.683294)
# (12, 0.553144, 0.664494)
# (13, 0.535785, 0.648713)
# (14, 0.521666, 0.635693)
# (15, 0.510315, 0.625104)
# (16, 0.501275, 0.616591)
# (17, 0.494129, 0.609811)
# (18, 0.485450, 0.601516)
# (19, 0.474203, 0.590667)
# (20, 0.459803, 0.576608)
# (21, 0.441645, 0.558608)
# (22, 0.419187, 0.535911)
# (23, 0.392064, 0.507839)
# (24, 0.360231, 0.473934)
# (25, 0.324105, 0.434144)
# (26, 0.284637, 0.388987)
# (27, 0.243266, 0.339651)
# (28, 0.201745, 0.287938)
# (29, 0.161848, 0.236036)
# (30, 0.125086, 0.186165)
# (31, 0.092496, 0.140212)
# (32, 0.064581, 0.099475)
# (Tray index, x_i_B, y_i_B)
# (1, 0.843110, 0.895814)
# (2, 0.770573, 0.843110)
# (3, 0.707611, 0.794752)
# ...

# %%
from pyjmi.examples import distillation
distillation.run_demo()
# Out:
#  *** Stationary point A ***
# (Tray index, x_i_A, y_i_A)
# (1, 0.935419, 0.958635)
# (2, 0.900526, 0.935419)
# (3, 0.862296, 0.909249)
# (4, 0.821699, 0.880577)
# (5, 0.779991, 0.850129)
# (6, 0.738572, 0.818848)
# (7, 0.698805, 0.787784)
# (8, 0.661843, 0.757959)
# (9, 0.628508, 0.730237)
# (10, 0.599253, 0.705236)
# (11, 0.574186, 0.683294)
# (12, 0.553144, 0.664494)
# (13, 0.535785, 0.648713)
# (14, 0.521665, 0.635693)
# (15, 0.510315, 0.625104)
# (16, 0.501275, 0.616591)
# (17, 0.494129, 0.609811)
# (18, 0.485450, 0.601516)
# (19, 0.474203, 0.590667)
# (20, 0.459803, 0.576608)
# (21, 0.441645, 0.558608)
# (22, 0.419187, 0.535911)
# (23, 0.392063, 0.507839)
# (24, 0.360231, 0.473934)
# (25, 0.324105, 0.434144)
# (26, 0.284637, 0.388987)
# (27, 0.243266, 0.339651)
# (28, 0.201745, 0.287938)
# (29, 0.161848, 0.236036)
# (30, 0.125085, 0.186165)
# (31, 0.092496, 0.140212)
# (32, 0.064581, 0.099474)
#  *** Stationary point B ***
# (Tray index, x_i_B, y_i_B)
# (1, 0.843110, 0.895814)
# ...
